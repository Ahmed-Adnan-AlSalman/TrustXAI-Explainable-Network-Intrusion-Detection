# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

print("Research Notebook Ready.")
# Out:
# Research Notebook Ready.

# %%
summary = """

===============================
TrustXAI Project Summary
===============================

Dataset
-------
CICIDS2017

Number of Classes
-----------------
12

Machine Learning Models
-----------------------
1. Random Forest
2. XGBoost

Explainable AI
--------------
1. SHAP
2. LIME

Evaluation Metrics
------------------
Accuracy
Precision
Recall
F1-Score

Final Best Model
----------------
XGBoost

Overall Accuracy
----------------
99.18%

"""

print(summary)
# Out:
# ...
# TrustXAI Project Summary
# ...
#
# Dataset
# -------
# CICIDS2017
#
# Number of Classes
# -----------------
# 12
#
# Machine Learning Models
# -----------------------
# 1. Random Forest
# 2. XGBoost
#
# Explainable AI
# --------------
# 1. SHAP
# 2. LIME
#
# Evaluation Metrics
# ------------------
# Accuracy
# Precision
# Recall
# F1-Score
#
# Final Best Model
# ----------------
# XGBoost
#
# Overall Accuracy
# ----------------
# 99.18%

# %%
contributions = [

"Developed a multiclass intrusion detection system.",

"Compared Random Forest with XGBoost.",

"Applied SHAP for global model explainability.",

"Applied LIME for local prediction explainability.",

"Performed comprehensive model evaluation.",

"Identified the most influential network traffic features.",

"Produced an explainable AI framework for cybersecurity."

]

for i, item in enumerate(contributions,1):
    print(f"{i}. {item}")
# Out:
# 1. Developed a multiclass intrusion detection system.
# 2. Compared Random Forest with XGBoost.
# 3. Applied SHAP for global model explainability.
# 4. Applied LIME for local prediction explainability.
# 5. Performed comprehensive model evaluation.
# 6. Identified the most influential network traffic features.
# 7. Produced an explainable AI framework for cybersecurity.

# %%
novelty = """

Novelty of the Proposed Framework

• Multiclass cyber attack detection.

• Explainable Artificial Intelligence.

• Comparison between two powerful ensemble models.

• Local and global explanations.

• High detection accuracy.

• Practical applicability for SOC analysts.

"""

print(novelty)
# Out:
# Novelty of the Proposed Framework
#
# • Multiclass cyber attack detection.
#
# • Explainable Artificial Intelligence.
#
# • Comparison between two powerful ensemble models.
#
# • Local and global explanations.
#
# • High detection accuracy.
#
# • Practical applicability for SOC analysts.

# %%
applications = [

"Security Operation Centers (SOC)",

"Enterprise Networks",

"Cloud Security",

"Industrial Control Systems",

"Critical Infrastructure",

"Smart Cities",

"IoT Security"

]

for app in applications:
    print("-",app)
# Out:
# - Security Operation Centers (SOC)
# - Enterprise Networks
# - Cloud Security
# - Industrial Control Systems
# - Critical Infrastructure
# - Smart Cities
# - IoT Security

# %%
impact = """

Research Impact

The proposed framework improves trust in machine learning
for cybersecurity by integrating Explainable AI methods.

Security analysts can understand why attacks are detected,
which increases transparency and confidence in automated
decision-making systems.

"""

print(impact)
# Out:
# Research Impact
#
# The proposed framework improves trust in machine learning
# for cybersecurity by integrating Explainable AI methods.
#
# Security analysts can understand why attacks are detected,
# which increases transparency and confidence in automated
# decision-making systems.

# %%
limitations = [

"Evaluated using CICIDS2017 dataset only.",

"Real-time deployment was not investigated.",

"Deep Learning models were not included.",

"Zero-day attacks require further investigation."

]

for item in limitations:
    print("-",item)
# Out:
# - Evaluated using CICIDS2017 dataset only.
# - Real-time deployment was not investigated.
# - Deep Learning models were not included.
# - Zero-day attacks require further investigation.

# %%
future = [

"Transformer-based IDS",

"Federated Learning",

"Online Learning",

"Edge AI",

"Cloud Deployment",

"Hybrid Explainability",

"Real-time Detection",

"Zero-Day Detection"

]

for item in future:
    print("-",item)
# Out:
# - Transformer-based IDS
# - Federated Learning
# - Online Learning
# - Edge AI
# - Cloud Deployment
# - Hybrid Explainability
# - Real-time Detection
# - Zero-Day Detection

# %%
steps = [

"Raw Dataset",

"Data Cleaning",

"Preprocessing",

"Feature Engineering",

"Balancing",

"Train/Test Split",

"Random Forest",

"XGBoost",

"Evaluation",

"SHAP",

"LIME",

"Model Comparison",

"Final Results"

]

plt.figure(figsize=(14,2))

plt.plot(range(len(steps)),np.ones(len(steps)),'o-',linewidth=3)

for i,s in enumerate(steps):

    plt.text(i,1.02,s,
             rotation=45,
             ha='right',
             fontsize=9)

plt.yticks([])

plt.xticks([])

plt.title("TrustXAI Pipeline")

plt.tight_layout()

plt.savefig(
    r"D:\TrustXAI\results\TrustXAI_Pipeline.png",
    dpi=300
)

plt.show()

# %%
statistics = pd.DataFrame({

"Item":[

"Dataset",

"Classes",

"Models",

"Explainability",

"Best Model",

"Accuracy"

],

"Value":[

"CICIDS2017",

"12",

"2",

"SHAP + LIME",

"XGBoost",

"99.18%"

]

})

statistics
# Out:
#              Item        Value
# 0         Dataset   CICIDS2017
# 1         Classes           12
# 2          Models            2
# 3  Explainability  SHAP + LIME
# 4      Best Model      XGBoost
# 5        Accuracy       99.18%

# %%
print("="*70)

print("TrustXAI Project Successfully Completed")

print("="*70)

print()

print("Notebook 01 : Data Loading")

print("Notebook 02 : Cleaning")

print("Notebook 03 : Preprocessing")

print("Notebook 04 : Feature Engineering")

print("Notebook 05 : Random Forest")

print("Notebook 06 : Evaluation")

print("Notebook 07 : Feature Importance")

print("Notebook 08 : SHAP")

print("Notebook 09 : LIME")

print("Notebook 10 : XGBoost")

print("Notebook 11 : Model Comparison")

print("Notebook 12 : Final Results")

print("Notebook 13 : Research Contribution")

print()

print("Project Status : COMPLETED")

print("="*70)
# Out:
# ...
# TrustXAI Project Successfully Completed
# ...
#
# Notebook 01 : Data Loading
# Notebook 02 : Cleaning
# Notebook 03 : Preprocessing
# Notebook 04 : Feature Engineering
# Notebook 05 : Random Forest
# Notebook 06 : Evaluation
# Notebook 07 : Feature Importance
# Notebook 08 : SHAP
# Notebook 09 : LIME
# Notebook 10 : XGBoost
# Notebook 11 : Model Comparison
# Notebook 12 : Final Results
# Notebook 13 : Research Contribution
#
# Project Status : COMPLETED
# ...
